# %% [markdown]
# # 1) 10 questions 45 min.
# # 2) Sample dataframe are given in questions, you can copy paste in cell and write the further code.
# # 3) *Kindly rename your notebook with your name before sending to us.
# # 4) *YOUR CODE MUST BE RUNNABLE IN OUR SYSTEM WITHOUT ANY ERROR.

# %% [markdown]
# ## Requirments

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from numpy import random

# %% [markdown]
# # 1) Create dataframe of the given list and assign auto-incremented number for each group.
# # lst = ['A', 'B', 'C', 'A','A','B','D','E','F','F','Z']
# e.g if A occures three times then 1st A will get 1 second will get 2 and third will get 3, same for B, 1st B will get 1 2nd will get 2 .....,C....etc. And get max number of each

# %%
lst = ['A', 'B', 'C', 'A','A','B','D','E','F','F','Z']

# %%
pd.DataFrame(lst)
# Out:
#     0
# 0   A
# 1   B
# 2   C
# 3   A
# 4   A
# 5   B
# 6   D
# 7   E
# 8   F
# 9   F
# 10  Z

# %% [markdown]
# # 2) Update the values column age and set it to 22 where name is "xyz" or "mnu" in given datarame using isin()
# data = [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 15], ['xyz', 14]]
# df = pd.DataFrame(data, columns = ['Name', 'Age'])

# %%
data = [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 15], ['xyz', 14]]
df = pd.DataFrame(data, columns = ['Name', 'Age'])

# %%
df
# Out:
#   Name  Age
# 0  xyz   10
# 1  abc   15
# 2  pzq   14
# 3  mnu   15
# 4  xyz   14

# %%
df['Name'].isin(['xyz', 'mnu'])
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Name, dtype: bool

# %%
df.loc[df.Name.isin(['xyz', 'mnu']), 'Age']=22

# %%
df
# Out:
#   Name  Age
# 0  xyz   22
# 1  abc   15
# 2  pzq   14
# 3  mnu   22
# 4  xyz   22

# %% [markdown]
# # 3) Print each alphabet of below string on new line using loop by removing white spaces.
#  "python is amazing"

# %%
s = "python is amazing"

# %%
for i in s:
    if i==" ":
        pass
    else:
        print(i)
# Out:
# p
# y
# t
# h
# o
# n
# i
# s
# a
# m
# a
# z
# i
# n
# g

# %% [markdown]
# # 4) Develop code for the following logic 01
# 1. Convert timestamp to date and add as a new feature date in dataset.
# 2. Get month number from date and add as a new feature month in dataset.
# 3. Get dayname from date and add as a new feature dayname in dataset.
#
# df = pd.DataFrame({'date':['20210101','20220201','19991001']})

# %%
df = pd.DataFrame({'date':['20210101','20220201','19991001']})

# %%
df
# Out:
#        date
# 0  20210101
# 1  20220201
# 2  19991001

# %%
df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#         date
# 0 2021-01-01
# 1 2022-02-01
# 2 1999-10-01

# %%
df['Month']  =df.date.dt.month

# %%
df['dayname'] = df['date'].dt.day_name()

# %%
df
# Out:
#         date  Month  dayname
# 0 2021-01-01      1   Friday
# 1 2022-02-01      2  Tuesday
# 2 1999-10-01     10   Friday

# %% [markdown]
# # 5) Data Visualization
# 1. From the below dataset, calculate the sum of sale values against each department
# 1. (after sum of "sale")plot variable department on x-axis, sale on y-axis
# 2. Give the names to the x-axis and y-axis, also add title to the plot by creating a self define function of name add_title()
#
#
# df = pd.DataFrame({'sale':[ 95228,  26413,  19699,  77988, 141460, 114889, 134434,  42803, 69876,  37574,  43581,  72795],
#                    'business':['A','B','B','C','A','B','A','A','C','C','B','A'],
#                   'department':['ABC','BCD','XYZ','ABC','ABC','XYZ','BCD','PQR','PQR','ABC','BCD','XYZ']})

# %%
df = pd.DataFrame({'sale':[ 95228, 26413, 19699, 77988, 141460, 114889, 134434, 42803, 69876, 37574, 43581, 72795], 
                   'business':['A','B','B','C','A','B','A','A','C','C','B','A'],
                   'department':['ABC','BCD','XYZ','ABC','ABC','XYZ','BCD','PQR','PQR','ABC','BCD','XYZ']})

# %%
df
# Out:
#       sale business department
# 0    95228        A        ABC
# 1    26413        B        BCD
# 2    19699        B        XYZ
# 3    77988        C        ABC
# 4   141460        A        ABC
# 5   114889        B        XYZ
# 6   134434        A        BCD
# 7    42803        A        PQR
# 8    69876        C        PQR
# 9    37574        C        ABC
# 10   43581        B        BCD
# 11   72795        A        XYZ

# %%
df.groupby(['department']).sum('sale')
# Out:
#               sale
# department
# ABC         352250
# BCD         204428
# PQR         112679
# XYZ         207383

# %%
df.groupby(['department']).sum('sale').plot()
# Out:
# <AxesSubplot:xlabel='department'>

# %%
def add_title():

# %% [markdown]
# # 6) Develop code for the following logic
# 1. Using below datset get the minimum, maximum and mean sales of each business.
# 2. Also get the minimum and maximum date for each business.
# 3. Merge above summarized information with orignal dataset. (df columns will be date, sale, business, MinimumSale, MaximumSale,MinimumDate,MaximumDate)
# 3. Sort the dataset using date for each business in descending order.
#
#
# df = pd.DataFrame({'date':['2021-04-01','2021-04-02','2021-04-03','2021-04-04','2021-04-05','2021-04-06',
#                            '2021-04-07','2021-04-08','2021-04-09','2021-04-10','2021-04-11','2021-04-12'],
#                    'sale':random.randint(10000,180000,12),
#                    'business':['A','B','B','C','A','B','A','A','C','C','B','A']})

# %%
df = pd.DataFrame({'date':['2021-04-01','2021-04-02','2021-04-03','2021-04-04','2021-04-05','2021-04-06', '2021-04-07','2021-04-08','2021-04-09','2021-04-10','2021-04-11','2021-04-12'], 
                   'sale':random.randint(10000,180000,12), 
                   'business':['A','B','B','C','A','B','A','A','C','C','B','A']})

# %%
df
# Out:
#           date    sale business
# 0   2021-04-01   67548        A
# 1   2021-04-02   31808        B
# 2   2021-04-03  154312        B
# 3   2021-04-04   83540        C
# 4   2021-04-05   34550        A
# 5   2021-04-06   36762        B
# 6   2021-04-07  157072        A
# 7   2021-04-08   56058        A
# 8   2021-04-09  168280        C
# 9   2021-04-10   29001        C
# 10  2021-04-11   35153        B
# 11  2021-04-12   39353        A

# %%
import numpy as np

# %%
df.groupby(['business']).agg({'sale':[np.min, np.max, np.mean]})
# Out:
#            sale
#            amin    amax      mean
# business
# A         34550  157072  70916.20
# B         31808  154312  64508.75
# C         29001  168280  93607.00

# %% [markdown]
# # 7) Develop code for the following logic 03
# 1. Using below dataset do the binning of month column. Make 4 binns 1-3,4-6,7-9,10-12 and name it as Quarter1, Quarter2, Quarter3 & Quarter4
# 2. Name this new column as a Quarter
#
# df = pd.DataFrame({'month':random.randint(1,12,12),
#                    'sale':random.randint(10000,180000,12),
#                    'business':['A','B','B','C','A','B','A','A','C','C','B','A']})

# %%
df = pd.DataFrame({'month':random.randint(1,12,12), 'sale':random.randint(10000,180000,12), 'business':['A','B','B','C','A','B','A','A','C','C','B','A']})

# %%
df
# Out:
#     month    sale business
# 0       5   92013        A
# 1      10  154091        B
# 2       1  127145        B
# 3       1   95233        C
# 4       2  116466        A
# 5       4  177011        B
# 6       1   34148        A
# 7       8   39838        A
# 8       7  113872        C
# 9       1   80936        C
# 10      5   19316        B
# 11     10   90586        A

# %% [markdown]
# # 8) join/merge the below dataframes on bussiness and local_business
#
# df1 LEFT JOIN df2
#
# df1 = pd.DataFrame({'sale':[ 95228,  26413,  19699,  77988, 141460, 114889, 134434,  42803, 69876,  37574,  43581,  72795],
#                    'business':['A','B','B','C','A','B','A','A','C','C','B','A'],
#                   'department':['ABC','BCD','XYZ','ABC','ABC','XYZ','BCD','PQR','PQR','ABC','BCD','XYZ']})
#
# df2 = pd.DataFrame({'local_business':['A','B','C'],
#                   'tax':['18%','25%','30%']})

# %%
df1 = pd.DataFrame({'sale':[ 95228, 26413, 19699, 77988, 141460, 114889, 134434, 42803, 69876, 37574, 43581, 72795], 'business':['A','B','B','C','A','B','A','A','C','C','B','A'], 'department':['ABC','BCD','XYZ','ABC','ABC','XYZ','BCD','PQR','PQR','ABC','BCD','XYZ']})

df2 = pd.DataFrame({'local_business':['A','B','C'], 'tax':['18%','25%','30%']})

# %%
df1
# Out:
#       sale business department
# 0    95228        A        ABC
# 1    26413        B        BCD
# 2    19699        B        XYZ
# 3    77988        C        ABC
# 4   141460        A        ABC
# 5   114889        B        XYZ
# 6   134434        A        BCD
# 7    42803        A        PQR
# 8    69876        C        PQR
# 9    37574        C        ABC
# 10   43581        B        BCD
# 11   72795        A        XYZ

# %%
df2
# Out:
#   local_business  tax
# 0              A  18%
# 1              B  25%
# 2              C  30%

# %%
df3 = df1.merge(df2, left_on='business', right_on='local_business')

# %%
df3
# Out:
#       sale business department local_business  tax
# 0    95228        A        ABC              A  18%
# 1   141460        A        ABC              A  18%
# 2   134434        A        BCD              A  18%
# 3    42803        A        PQR              A  18%
# 4    72795        A        XYZ              A  18%
# 5    26413        B        BCD              B  25%
# 6    19699        B        XYZ              B  25%
# 7   114889        B        XYZ              B  25%
# 8    43581        B        BCD              B  25%
# 9    77988        C        ABC              C  30%
# 10   69876        C        PQR              C  30%
# 11   37574        C        ABC              C  30%

# %% [markdown]
# # 9) From below dataset select the countries whose region contain word 'Asia'
#
#
# df = pd.DataFrame({'country':['Afghanistan','Albania','Algeria','American Samoa','Andorra','Angola','Anguilla','Antarctica','Antigua and Barbuda','Argentina','Armenia','Aruba','Australia','Austria','Azerbaijan','Bahamas','Bahrain','Bangladesh','Barbados','Belarus','Belgium','Belize','Benin','Bermuda','Bhutan','Bolivia','Bosnia and Herzegovina','Botswana','Brazil','Brunei Darussalam','Bulgaria','Burkina Faso','Burundi','Cambodia','Cameroon','Canada','Cape Verde','Cayman Islands','Central African Republic','Chad','Chile','China','Christmas Island','Cocos (Keeling) Islands','Colombia','Comoros','Democratic Republic of the Congo (Kinshasa)','Congo Republic of (Brazzaville)','Cook Islands','Costa Rica','Côte Divoire (Ivory Coast)','Croatia','Cuba','Cyprus','Czech Republic','Denmark','Djibouti','Dominica','Dominican Republic'],
#                    'Region':['South-Central Asia','Balkan Peninsula','Northern Africa','Polynesia Oceania','Southern Europe','Central Africa','Leeward Islands Caribbean','Antarctica','Leeward Islands Caribbean','Southern South America','Western Asia','Leeward Islands Caribbean','Australia/Oceania','Western Europe','Caucasus Western Asia','Caribbean','Arabian Peninsula Middle East','South-Central Asia','Lesser Antilles Caribbean','Eastern Europe','Western Europe','Central America','West Africa','North America','South-Central Asia','Central South America','Southern Europe','Southern Africa','Central Eastern South America','Southeast Asia','Balkan Eastern Europe','West Africa','Eastern Africa African Great Lakes','South-East Asia','Central Africa','North North America','West Africa','Greater Antilles Caribbean','Central Africa','Central Africa','Western South America','Eastern Asia','Southeast Asia','South-East Asia Australia','North West South America','Eastern Africa','Central Africa','Central Africa','Polynesia Oceania','Central America','West Africa','Balkan Peninsula Southern Europe','Greater Antilles Caribbean','Mediterranean Western Asia','Eastern Europe','Northern Europe','Eastern Africa','Lesser Antilles Caribbean','Greater Antilles Caribbean']})
#
#
# `Note: This is generated data so country name & region name should be mismatch`

# %%
df = pd.DataFrame({'country':['Afghanistan','Albania','Algeria','American Samoa','Andorra','Angola','Anguilla','Antarctica','Antigua and Barbuda','Argentina','Armenia','Aruba','Australia','Austria','Azerbaijan','Bahamas','Bahrain','Bangladesh','Barbados','Belarus','Belgium','Belize','Benin','Bermuda','Bhutan','Bolivia','Bosnia and Herzegovina','Botswana','Brazil','Brunei Darussalam','Bulgaria','Burkina Faso','Burundi','Cambodia','Cameroon','Canada','Cape Verde','Cayman Islands','Central African Republic','Chad','Chile','China','Christmas Island','Cocos (Keeling) Islands','Colombia','Comoros','Democratic Republic of the Congo (Kinshasa)','Congo Republic of (Brazzaville)','Cook Islands','Costa Rica','Côte Divoire (Ivory Coast)','Croatia','Cuba','Cyprus','Czech Republic','Denmark','Djibouti','Dominica','Dominican Republic'], 'Region':['South-Central Asia','Balkan Peninsula','Northern Africa','Polynesia Oceania','Southern Europe','Central Africa','Leeward Islands Caribbean','Antarctica','Leeward Islands Caribbean','Southern South America','Western Asia','Leeward Islands Caribbean','Australia/Oceania','Western Europe','Caucasus Western Asia','Caribbean','Arabian Peninsula Middle East','South-Central Asia','Lesser Antilles Caribbean','Eastern Europe','Western Europe','Central America','West Africa','North America','South-Central Asia','Central South America','Southern Europe','Southern Africa','Central Eastern South America','Southeast Asia','Balkan Eastern Europe','West Africa','Eastern Africa African Great Lakes','South-East Asia','Central Africa','North North America','West Africa','Greater Antilles Caribbean','Central Africa','Central Africa','Western South America','Eastern Asia','Southeast Asia','South-East Asia Australia','North West South America','Eastern Africa','Central Africa','Central Africa','Polynesia Oceania','Central America','West Africa','Balkan Peninsula Southern Europe','Greater Antilles Caribbean','Mediterranean Western Asia','Eastern Europe','Northern Europe','Eastern Africa','Lesser Antilles Caribbean','Greater Antilles Caribbean']})

# %%
df
# Out:
#                                         country  \
# 0                                   Afghanistan
# 1                                       Albania
# 2                                       Algeria
# 3                                American Samoa
# 4                                       Andorra
# 5                                        Angola
# 6                                      Anguilla
# 7                                    Antarctica
# 8                           Antigua and Barbuda
# 9                                     Argentina
# 10                                      Armenia
# 11                                        Aruba
# 12                                    Australia
# 13                                      Austria
# 14                                   Azerbaijan
# 15                                      Bahamas
# 16                                      Bahrain
# 17                                   Bangladesh
# 18                                     Barbados
# 19                                      Belarus
# 20                                      Belgium
# 21                                       Belize
# 22                                        Benin
# 23                                      Bermuda
# 24                                       Bhutan
# 25                                      Bolivia
# 26                       Bosnia and Herzegovina
# 27                                     Botswana
# 28                                       Brazil
# 29                            Brunei Darussalam
# 30                                     Bulgaria
# 31                                 Burkina Faso
# 32                                      Burundi
# 33                                     Cambodia
# 34                                     Cameroon
# 35                                       Canada
# 36                                   Cape Verde
# 37                               Cayman Islands
# 38                     Central African Republic
# 39                                         Chad
# 40                                        Chile
# 41                                        China
# 42                             Christmas Island
# 43                      Cocos (Keeling) Islands
# 44                                     Colombia
# 45                                      Comoros
# 46  Democratic Republic of the Congo (Kinshasa)
# 47              Congo Republic of (Brazzaville)
# 48                                 Cook Islands
# 49                                   Costa Rica
# 50                   Côte Divoire (Ivory Coast)
# 51                                      Croatia
# 52                                         Cuba
# 53                                       Cyprus
# 54                               Czech Republic
# 55                                      Denmark
# 56                                     Djibouti
# 57                                     Dominica
# 58                           Dominican Republic
#
#                                 Region
# 0                   South-Central Asia
# 1                     Balkan Peninsula
# 2                      Northern Africa
# 3                    Polynesia Oceania
# 4                      Southern Europe
# 5                       Central Africa
# 6            Leeward Islands Caribbean
# 7                           Antarctica
# 8            Leeward Islands Caribbean
# 9               Southern South America
# 10                        Western Asia
# 11           Leeward Islands Caribbean
# 12                   Australia/Oceania
# 13                      Western Europe
# 14               Caucasus Western Asia
# 15                           Caribbean
# 16       Arabian Peninsula Middle East
# 17                  South-Central Asia
# 18           Lesser Antilles Caribbean
# 19                      Eastern Europe
# 20                      Western Europe
# 21                     Central America
# 22                         West Africa
# 23                       North America
# 24                  South-Central Asia
# 25               Central South America
# 26                     Southern Europe
# 27                     Southern Africa
# 28       Central Eastern South America
# 29                      Southeast Asia
# 30               Balkan Eastern Europe
# 31                         West Africa
# 32  Eastern Africa African Great Lakes
# 33                     South-East Asia
# 34                      Central Africa
# 35                 North North America
# 36                         West Africa
# 37          Greater Antilles Caribbean
# 38                      Central Africa
# 39                      Central Africa
# 40               Western South America
# 41                        Eastern Asia
# 42                      Southeast Asia
# 43           South-East Asia Australia
# 44            North West South America
# 45                      Eastern Africa
# 46                      Central Africa
# 47                      Central Africa
# 48                   Polynesia Oceania
# 49                     Central America
# 50                         West Africa
# 51    Balkan Peninsula Southern Europe
# 52          Greater Antilles Caribbean
# 53          Mediterranean Western Asia
# 54                      Eastern Europe
# 55                     Northern Europe
# 56                      Eastern Africa
# 57           Lesser Antilles Caribbean
# 58          Greater Antilles Caribbean

# %%
df.head()
# Out:
#           country              Region
# 0     Afghanistan  South-Central Asia
# 1         Albania    Balkan Peninsula
# 2         Algeria     Northern Africa
# 3  American Samoa   Polynesia Oceania
# 4         Andorra     Southern Europe

# %%
df_Asia = df[df['Region'].str.contains('Asia')]

# %%
df_Asia
# Out:
#                     country                      Region
# 0               Afghanistan          South-Central Asia
# 10                  Armenia                Western Asia
# 14               Azerbaijan       Caucasus Western Asia
# 17               Bangladesh          South-Central Asia
# 24                   Bhutan          South-Central Asia
# 29        Brunei Darussalam              Southeast Asia
# 33                 Cambodia             South-East Asia
# 41                    China                Eastern Asia
# 42         Christmas Island              Southeast Asia
# 43  Cocos (Keeling) Islands   South-East Asia Australia
# 53                   Cyprus  Mediterranean Western Asia

# %% [markdown]
# # 10) create new column and add 15 in age for each record where age>=20 using lambda function
# data = [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 20], ['xyz', 21]]
# df = pd.DataFrame(data, columns = ['Name', 'Age'])

# %%
data = [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 20], ['xyz', 21]]

# %%
df = pd.DataFrame(data, columns = ['Name', 'Age'])

# %%
data
# Out:
# [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 20], ['xyz', 21]]

# %%
df
# Out:
#   Name  Age
# 0  xyz   10
# 1  abc   15
# 2  pzq   14
# 3  mnu   20
# 4  xyz   21

# %%
d = lambda x: x.assign(new_col= x['Age']>=20)

# %%
df = d(df)
df
# Out:
#   Name  Age  new_col
# 0  xyz   10    False
# 1  abc   15    False
# 2  pzq   14    False
# 3  mnu   20     True
# 4  xyz   21     True

# %%
df['new_col'] = np.where(df.new_col==True,15, df.Age)

# %%
df
# Out:
#   Name  Age  new_col
# 0  xyz   10       10
# 1  abc   15       15
# 2  pzq   14       14
# 3  mnu   20       20
# 4  xyz   21       21
